# %% [markdown]
# <a href="https://colab.research.google.com/github/wajihh/genai_batch62_assignments/blob/main/Student_Performance_Tracker/student_perform_track.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Project Objective**
#
# This project demonstrates a Student Performance Tracker built using Python. It allows a teacher to input student scores, track performance across subjects, and calculate statistics such as averages and feedback on passing or failing. The project utilizes Object-Oriented Programming (OOP), loops, conditionals, and data structures (lists and dictionaries).
#
# ##Project Structure
# The project is built around a Student class which encapsulates the attributes and methods for a student object.
#
# ###1. Student Class:
#
# __init__(self, name): Initializes a new Student object with a name and an empty dictionary scores to store subject scores.
# add_score(self, subject, score): Adds a subject and its corresponding score to the scores dictionary. It validates that the score is between 0 and 100, printing an error message if it is not.
# get_average_score(self): Calculates and returns the average score across all subjects. Includes a check to handle cases where no scores have been recorded, preventing a ZeroDivisionError. Returns 0 if there are no scores.
# get_feedback(self): Returns a feedback string ("Passing" or "Failing") based on the average score. A passing score is defined as 70 or higher.
# get_subject_score(self, subject): Retrieves score for a given subject. If score does not exist, a message "No score recorded for this subject." is returned.
#
# ##2. Main Function (main)
#
# Initialization: Creates an empty list students to store Student objects.
# Main Loop: The core program loop that presents a menu to the user.
# Menu Options:
# 1. Add Student: Prompts for a student's name, creates a new Student object, and adds it to the students list.
# 2. Add Score: Prompts for a student's name, subject, and score. Then it finds the student in the list, validates the input, and adds the score using the add_score method. Handles the case where no students have been added. It searches for the student by name.
# 3. View Student Report: Prompts for a student's name. If the student exists, it prints the subject scores, calculates and prints the average score, and gives overall feedback. If the student does not exist, it provides a "Student not found." message. Handles the case where no scores have been recorded for the student. It searches for the student by name.
# 4. Exit: Exits the program.
# Error Handling: Provides feedback to the user for invalid choices and handles situations like no students added or student not found.
# 3. Execution ** Themain()` function only executes when the script is run directly, not when imported as a module.
#
# ## How to Run the Code
#
# Save: Save the code as a Python file (e.g., student_tracker.ipny).
# Run: Execute the script from your terminal using python student_tracker.ipynb.

# %%
# Project Develop a Student Performance Tracker using Python, which allows a teacher to input student scores,
# track performance across subjects, and calculate statistics such as averages and feedback on passing or failing,
# using concepts in Object-Oriented Programming (OOP), loops, conditionals, and data structures (lists and dictionaries)

class Student:
    def __init__(self, name):
        self.name = name
        self.scores = {}

    def add_score(self, subject, score):
        if 0 <= score <= 100:
            self.scores[subject] = score
        else:
            print("Invalid score. Score must be between 0 and 100.")

    def get_average_score(self):
        if not self.scores:
            return 0  # Handle case with no scores
        return sum(self.scores.values()) / len(self.scores)

    def get_subject_score(self, subject):
      return self.scores.get(subject, "No score recorded for this subject.")

    def get_feedback(self):
        average_score = self.get_average_score()
        if average_score >= 70:
            return "Passing"
        else:
            return "Failing"


def main():
    students = []
    while True:
        print("\nStudent Performance Tracker Menu:")
        print("1. Add Student")
        print("2. Add Score")
        print("3. View Student Report")
        print("4. Exit")

        choice = input("Enter your choice: ")

        if choice == '1':
            name = input("Enter student name: ")
            students.append(Student(name))
            print(f"Student {name} added.")

        elif choice == '2':
            if not students:
                print("No students added yet.")
                continue

            name = input("Enter student name: ")
            student = next((s for s in students if s.name == name), None)

            if student:
                subject = input("Enter subject: ")
                score = int(input("Enter score: "))
                student.add_score(subject, score)
                print("Score added.")
            else:
                print("Student not found.")

        elif choice == '3':
          if not students:
              print("No students added yet.")
              continue

          name = input("Enter student name: ")
          student = next((s for s in students if s.name == name), None)
          if student:
              print(f"\n--- Report for {student.name} ---")
              if student.scores:
                  for subject, score in student.scores.items():
                      print(f"{subject}: {score}")

                  average = student.get_average_score()
                  print(f"\nAverage Score: {average:.2f}")
                  print(f"Overall Feedback: {student.get_feedback()}")
              else:
                  print("No scores recorded for this student.")
          else:
              print("Student not found.")

        elif choice == '4':
            print("Exiting program.")
            break
        else:
            print("Invalid choice. Please try again.")


if __name__ == "__main__":
    main()
# Out:
# Student Performance Tracker Menu:
# 1. Add Student
# 2. Add Score
# 3. View Student Report
# 4. Exit
# Enter your choice: 1
# Enter student name: Aijaz
# Student Aijaz added.
#
# Student Performance Tracker Menu:
# 1. Add Student
# 2. Add Score
# 3. View Student Report
# 4. Exit
# Enter your choice: 2
# Enter student name: Aijaz
# Enter subject: Maths
# Enter score: 98
# Score added.
#
# Student Performance Tracker Menu:
# 1. Add Student
# 2. Add Score
# 3. View Student Report
# 4. Exit
# Enter your choice: 1
# Enter student name: Fawad
# Student Fawad added.
#
# Student Performance Tracker Menu:
# 1. Add Student
# 2. Add Score
# 3. View Student Report
# 4. Exit
# Enter your choice: 2
# Enter student name: Fawad
# Enter subject: Maths
# Enter score: 90
# Score added.
#
# Student Performance Tracker Menu:
# 1. Add Student
# 2. Add Score
# 3. View Student Report
# 4. Exit
# Enter your choice: 1
# Enter student name: Ali
# Student Ali added.
#
# Student Performance Tracker Menu:
# 1. Add Student
# 2. Add Score
# 3. View Student Report
# 4. Exit
# Enter your choice: 2
# Enter student name: Ali
# Enter subject: 95
# Enter score: 2
# Score added.
#
# Student Performance Tracker Menu:
# 1. Add Student
# 2. Add Score
# 3. View Student Report
# 4. Exit
# Enter your choice: Ali
# Invalid choice. Please try again.
#
# Student Performance Tracker Menu:
# 1. Add Student
# 2. Add Score
# 3. View Student Report
# 4. Exit
# Enter your choice: 2
# Enter student name: Ali
# Enter subject: Maths
# Enter score: 95
# Score added.
#
# Student Performance Tracker Menu:
# 1. Add Student
# 2. Add Score
# 3. View Student Report
# 4. Exit
# Enter your choice: 3
# Enter student name: Ali
#
# --- Report for Ali ---
# 95: 2
# Maths: 95
#
# Average Score: 48.50
# Overall Feedback: Failing
#
# Student Performance Tracker Menu:
# 1. Add Student
# 2. Add Score
# 3. View Student Report
# 4. Exit
# Enter your choice: 4
# Exiting program.
